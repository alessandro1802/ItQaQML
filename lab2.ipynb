# %% [markdown]
# # Bell states
# Oleksandr Yasinskyi 150570

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer
from qiskit.visualization import *
# Selection of quantum simulator (or processor)
backend = Aer.get_backend('qasm_simulator')

# %% [markdown]
# ## Task 1: Create the Bell state |Φ+>

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.draw(output='mpl', style="clifford")

# %%
seria = 2048  # Number of trials in a series of measurements of a given type

# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'00': 1042, '11': 1006}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 2: : Create the Bell state |Φ->

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'11': 1000, '00': 1048}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 3: Create the Bell state |Ψ+>

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 1017, '10': 1031}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 4: Create the Bell state |Ψ->

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.x(qreg_q[0])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 1031, '10': 1017}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 5: XX measurement for circuits

# %% [markdown]
# ### 1.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'11': 1031, '00': 1017}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 2.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'10': 1015, '01': 1033}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 3.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'11': 1058, '00': 990}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 4.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.x(qreg_q[0])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'10': 1032, '01': 1016}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 6: YY measurement for circuits

# %% [markdown]
# ### 1.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.sdg(qreg_q[0])
circuit.sdg(qreg_q[1])
circuit.h(qreg_q[1])
circuit.h(qreg_q[0])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 1030, '10': 1018}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 2.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.sdg(qreg_q[0])
circuit.sdg(qreg_q[1])
circuit.h(qreg_q[1])
circuit.h(qreg_q[0])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'11': 1018, '00': 1030}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 3.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.sdg(qreg_q[0])
circuit.sdg(qreg_q[1])
circuit.h(qreg_q[1])
circuit.h(qreg_q[0])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'00': 1064, '11': 984}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 4.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.x(qreg_q[0])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.sdg(qreg_q[0])
circuit.sdg(qreg_q[1])
circuit.h(qreg_q[1])
circuit.h(qreg_q[0])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 1031, '10': 1017}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ## Task 7: XZ measurement for circuits

# %% [markdown]
# ### 1.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 481, '00': 517, '10': 516, '11': 534}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 2.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 524, '11': 515, '10': 485, '00': 524}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 3.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 508, '00': 516, '11': 489, '10': 535}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)

# %% [markdown]
# ### 4.

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[1])
circuit.x(qreg_q[0])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[1])

# %%
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuit, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
counts = sim_resultX.get_counts(circuit)
print(counts)
# Out:
# {'01': 484, '00': 558, '10': 515, '11': 491}

# %%
plot_histogram(counts)

# %%
plot_distribution(counts)
