# %% [markdown]
# # Project 1: Analysis of the operation of quantum gates and simple quantum circuits

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from numpy import pi
# selection of quantum simulator (or processor)
backend = Aer.get_backend('qasm_simulator')

from qiskit import BasicAer
from qiskit.visualization import plot_state_city, plot_bloch_multivector, plot_state_hinton, plot_state_qsphere, plot_state_paulivec

# %% [markdown]
# ## Task 1
# Z-type projection measurement – reading of the qubit state

# %% [markdown]
# #### Quiskit

# %%
n=4 # determining the number of quantum and classical registers
seria=2048 # number of trials in a series of measurements of a given type
# Example of measuring the state of qubit q[0]
nx = n # Number of qubits and bits

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.measure(qx[0], cx[0]) # Checking the states of qubits - quantum measurement
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0000': 2048}

# %% [markdown]
# #### Additional task

# %%
def get_psi(circuit):
    # execute the quantum circuit
    backend = BasicAer.get_backend('statevector_simulator') # the device to run on
    result = backend.run(transpile(circuit, backend)).result()
    return result.get_statevector(circuit)

# %%
psi = get_psi(circuitX)

# %%
plot_state_city(psi)

# %%
plot_state_hinton(psi)

# %%
plot_state_qsphere(psi)

# %%
plot_bloch_multivector(psi)

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task1.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task1.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task1.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task1.png)

# %% [markdown]
# ## Task 2
# Quantum gate X = quantum negation

# %% [markdown]
# #### Quiskit

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.x(qx[0])
circuitX.measure(qx[0], cx[0]) # Checking the states of qubits - quantum measurement
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0001': 2048}

# %% [markdown]
# #### Additional task

# %%
psi = get_psi(circuitX)

# %%
plot_state_city(psi)

# %%
plot_state_hinton(psi)

# %%
plot_state_qsphere(psi)

# %%
plot_bloch_multivector(psi)

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task2.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task2.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task2.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task2.png)

# %% [markdown]
# ## Task 3: Superposition of states

# %% [markdown]
# #### Quiskit

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.h(qx[0])
circuitX.measure(qx[0], cx[0]) # Checking the states of qubits - quantum measurement
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0001': 993, '0000': 1055}

# %% [markdown]
# #### Additional task

# %%
psi = get_psi(circuitX)

# %%
plot_state_city(psi)

# %%
plot_state_hinton(psi)

# %%
plot_state_qsphere(psi)

# %%
plot_bloch_multivector(psi)

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task3.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task3.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task3.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task3.png)

# %% [markdown]
# ## Task 4: State tomography of one qubit – implementations on a quantum computer

# %% [markdown]
# ### Measurement in the X base

# %% [markdown]
# #### Quiskit

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.ry(pi / 2, qx[0])
circuitX.p(pi / 2, qx[0])
circuitX.h(qx[0])
circuitX.measure(qx[0], cx[0])
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0001': 1022, '0000': 1026}

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task4-x.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task4-x.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task4-x.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task4-x.png)

# %% [markdown]
# ### Measurement in the Y base

# %% [markdown]
# #### Quiskit

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.ry(pi / 2, qx[0])
circuitX.p(pi / 2, qx[0])
circuitX.sdg(qx[0])
circuitX.h(qx[0])
circuitX.measure(qx[0], cx[0])
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0000': 2048}

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task4-y.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task4-y.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task4-y.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task4-y.png)

# %% [markdown]
# ### Measurement in the Z base

# %% [markdown]
# #### Quiskit

# %%
qx = QuantumRegister(nx) #
cx = ClassicalRegister(nx) #
circuitX = QuantumCircuit(qx, cx) # Quantum algorithm - quantum circuit

# %%
circuitX.ry(pi / 2, qx[0])
circuitX.p(pi / 2, qx[0])
circuitX.measure(qx[0], cx[0])
circuitX.draw(output='mpl', style="clifford")

# %%
# Performing quantum calculations
job_simX = execute(circuitX, backend, shots=seria)
sim_resultX = job_simX.result()
# Numerical presentation of measurement results
print(sim_resultX.get_counts(circuitX))
# Graphical presentation of measurement results
plot_histogram(sim_resultX.get_counts(circuitX))
# Out:
# {'0001': 1003, '0000': 1045}

# %% [markdown]
# #### IBM Quantum Composer
# ##### Circuit
# ![title](./Composer/lab1/circuit/task4-z.png)
#
# ##### Probabilities
# ![title](./Composer/lab1/probabilities/task4-z.png)
#
# ##### Statevector
# ![title](./Composer/lab1/statevector/task4-z.png)
#
# ##### Q-sphere
# ![title](./Composer/lab1/Q-sphere/task4-z.png)
